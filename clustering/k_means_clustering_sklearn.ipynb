# %% [markdown]
# # K-Means Clustering Example

# %%
## Importing Libraries

from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
## Loading Dataset

# Load the Iris dataset (use y lables for verifying the results)
iris_X, iris_y = load_iris(return_X_y=True)

# %%
## Model Building

# Create KMeans object
kmeans = KMeans(n_clusters=3, random_state=0)

# Fit clustering and return the cluster lables for dataset
clusters = kmeans.fit_predict(iris_X)

# Get cluster labels for each data points in dataset
labels = kmeans.labels_

# Get cluster centres
centers = kmeans.cluster_centers_

# %% [markdown]
# ## Elbow Method for finding the optimal value of k

# %%
# wcss - Within Cluster Sum of Squares (WCSS)
wcss = []

for i in range(1, 15):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(iris_X)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 15), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\ashish.kamboj\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## Finding the appropriate number of cluters(k) - Using silhouette coefficient

# %%
from sklearn.metrics import silhouette_score

# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(iris_X)
    score = silhouette_score(iris_X, kmeans.labels_)
    silhouette_coefficients.append(score)
    
plt.plot(range(2, 15), silhouette_coefficients)
plt.xticks(range(2, 15))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
# K-Means Clustering object with default parameter values- detailed

"""
kmeans = KMeans(n_clusters=8, 
                 init='k-means++', 
                 n_init=10, 
                 max_iter=300, 
                 tol=0.0001, 
                 verbose=0, 
                 random_state=None,
                 copy_x=True, 
                 algorithm='auto')

"""
